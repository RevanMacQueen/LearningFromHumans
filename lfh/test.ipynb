# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
n = np.load("returns.npy", allow_pickle=True)

# %%
n = n.astype(float)
n = np.nan_to_num(n)

# %%
cum_n = np.cumsum(n)

# %%
cum_n
# Out:
# array([    0.,     0.,     0., ..., 54452., 54453., 54456.])

# %%
plt.scatter(range(len(n)),n)
plt.savefig("breakout_rewards_2_million_episodezpd.png", bbox_inches = "tight")
plt.show()

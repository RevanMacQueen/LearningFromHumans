# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
n = np.load("results\\_breakout_standard_2020-11-30-16-48_s64811\\returns.npy", allow_pickle=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-fe1ba25bd0df> in <module>
# ----> 1 n = np.load("results\\_breakout_standard_2020-11-30-16-39_s64811\\returns.npy", allow_pickle=True)
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\numpy\lib\npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     414             own_fid = False
#     415         else:
# --> 416             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     417             own_fid = True
#     418
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results\\_breakout_standard_2020-11-30-16-39_s64811\\returns.npy'

# %%
n = n.astype(float)
n = np.nan_to_num(n)

# %%
cum_n = np.cumsum(n)

# %%
cum_n
# Out:
# array([  0.,   0.,   0., ..., 733., 733., 734.])

# %%
plt.scatter(range(len(n)),n)
plt.savefig("breakout_rewards_2_million_episodezpd.png", bbox_inches = "tight")
plt.show()
